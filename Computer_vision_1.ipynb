# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gorilla_np = plt.imread('../computer_vision/gorilla.jpg')

# %%
gorilla_np.shape
# Out:
# (1295, 1955, 3)

# %%
plt.imshow(gorilla_np)

# %%
# Use slicing to set the RED and GREEN channels of the picture to 0, then use imshow() to show the isolated blue channel

# %%
gor_blue = gorilla_np.copy()

# %%
gor_blue[:,:,0] = 0 # set Red channel to 0
gor_blue[:,:,1] = 1 # set Green channel to 0
plt.imshow(gor_blue)

# %%
import cv2

# %%
# read image using cv2
img = cv2.imread('../computer_vision/gorilla.jpg')

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('../computer_vision/gorilla.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img.shape
# Out:
# (1295, 1955, 3)

# %%
resized_img = cv2.resize(img,(1000,1000))

# %%
plt.imshow(resized_img)

# %%
flip_nm = [0,1,-1]

# %%
 
new_i = cv2.flip(img,-1)
plt.imshow(new_i)

# %%
new_i = cv2.flip(img,0)
plt.imshow(new_i)
